# %%
import pandas as pd

# %%
mapping = {}

# Age and Sex
mapping["S0101_C01_001E"] = "Estimate!!Total!!Total population"
for i in range(2, 20):
    mapping[f"S0101_C01_{i:03d}E"] = "Estimate!!Total!!Age Categories"

mapping["S0101_C03_001E"] = "Estimate!!Male!!Total population"
for i in range(2, 20):
    mapping[f"S0101_C03_{i:03d}E"] = "Estimate!!Male!!Age Categories"

mapping["S0101_C05_001E"] = "Estimate!!Female!!Total population"
for i in range(2, 20):
    mapping[f"S0101_C05_{i:03d}E"] = "Estimate!!Female!!Age Categories"

# Race
for j in range(2, 9):
    mapping[f"B02001_00{j}E"] = "Estimate!!Total:!!Race Categories"

# Employment Status
mapping["S2301_C01_001E"] = "Estimate!!Total!!Population 16 years and over"
for i in range(2, 12):
    mapping[f"S2301_C01_{i:03d}E"] = "Estimate!!Total!!Population 16 years and over!!AGE!!Age Categories"

# Earnings
mapping["S2001_C01_001E"] = "Estimate!!Total!!Population 16 years and over with earnings"

# Population Under 18 Years
mapping["B09001_001E"] = "Estimate!!Total:"

# Marital Status
mapping["S1201_C01_001E"] = "Estimate!!Total!!Population 15 years and over   Marital Status (?)"
mapping["DP02_0025E"] = "Estimate!!MARITAL STATUS!!Males 15 years and over"
for i in range(26, 31):
    mapping[f"DP02_{i:04d}E"] = "Estimate!!MARITAL STATUS!!Males 15 years and over!!Marital Categories"
mapping["DP02_0031E"] = "Estimate!!MARITAL STATUS!!Females 15 years and over"
for i in range(32, 37):
    mapping[f"DP02_{i:04d}E"] = "Estimate!!MARITAL STATUS!!Females 15 years and over!!Marital Categories"

# Occupancy Characteristics
mapping["S2501_C01_001E"] = "Estimate!!Occupied housing units!!Occupied housing units"
mapping["S2501_C01_009E"] = "Estimate!!Occupied housing units!!Occupied housing units!!HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER!!Family households"
mapping["S2501_C01_010E"] = "Estimate!!Occupied housing units!!Occupied housing units!!HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER!!Family households!!Married-couple family"
mapping["S2501_C01_014E"] = "Estimate!!Occupied housing units!!Occupied housing units!!HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER!!Family households!!Other family"
mapping["S2501_C01_015E"] = "Estimate!!Occupied housing units!!Occupied housing units!!HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER!!Family households!!Other family!!Male householder, no spouse present"
mapping["S2501_C01_019E"] = "Estimate!!Occupied housing units!!Occupied housing units!!HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER!!Family households!!Female householder, no spouse present"
mapping["S2501_C01_023E"] = "Estimate!!Occupied housing units!!Occupied housing units!!HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER!!Nonfamily households"
mapping["S2501_C01_024E"] = "Estimate!!Occupied housing units!!Occupied housing units!!HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER!!Nonfamily households!!Householder living alone"
mapping["S2501_C01_028E"] = "Estimate!!Occupied housing units!!Occupied housing units!!HOUSEHOLD TYPE (INCLUDING LIVING ALONE) AND AGE OF HOUSEHOLDER!!Nonfamily households!!Householder not living alone"

# Selected Housing Characteristics
veh_desc = {58: "No vehicles available", 59: "1 vehicle available", 60: "2 vehicles available", 61: "3 or more vehicles available"}
for code, desc in veh_desc.items():
    mapping[f"DP04_00{code}E"] = f"Estimate!!VEHICLES AVAILABLE!!Occupied housing units!!{desc}"

# Work Status in the Past 12 Months
mapping["S2303_C01_001E"] = "Estimate!!Total!!Population 16 to 64 years"
weeks = {
    2: "Worked 50 to 52 weeks", 3: "Worked 48 to 49 weeks", 4: "Worked 40 to 47 weeks",
    5: "Worked 27 to 39 weeks", 6: "Worked 14 to 26 weeks", 7: "Worked 1 to 13 weeks", 8: "Did not work"
}
for code, desc in weeks.items():
    mapping[f"S2303_C01_{code:03d}E"] = f"Estimate!!Total!!Population 16 to 64 years!!WEEKS WORKED!!{desc}"

hours = {
    9: "Usually worked 35 or more hours per week",
    16: "Usually worked 15 to 34 hours per week",
    23: "Usually worked 1 to 14 hours per week"
}
for code, desc in hours.items():
    mapping[f"S2303_C01_{code:03d}E"] = f"Estimate!!Total!!Population 16 to 64 years!!USUAL HOURS WORKED!!{desc}"

# Educational Attainment
mapping["S1501_C01_001E"] = "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years"
for i in range(2, 6):
    mapping[f"S1501_C01_{i:03d}E"] = "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!edu categories"
mapping["S1501_C01_006E"] = "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 25 years and over"
edu = {
    7: "Less than 9th grade", 8: "9th to 12th grade, no diploma",
    9: "High school graduate (includes equivalency)", 10: "Some college, no degree",
    11: "Associate's degree", 12: "Bachelor's degree", 13: "Graduate or professional degree"
}
for code, desc in edu.items():
    mapping[f"S1501_C01_{code:03d}E"] = f"Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 25 years and over!!{desc}"

# Households and Families
mapping["S1101_C01_001E"] = "Estimate!!Total!!HOUSEHOLDS!!Total households"
mapping["S1101_C01_005E"] = "Estimate!!Total!!AGE OF OWN CHILDREN!!Households with own children of the householder under 18 years"

# %%
pd.DataFrame.from_dict(mapping, orient="index", columns=["Label"]).to_csv(
    "census_mapping.csv",
    index_label="Variable",
    quoting=1,
    encoding="utf-8-sig"
)
